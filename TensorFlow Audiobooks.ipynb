# %%
import numpy as np
import tensorflow as tf

# %%
npz = np.load('Audiobooks_data_train.npz')

train_inputs = npz['inputs'].astype(np.float)
train_targets = npz['targets'].astype(np.int)

npz = np.load('Audiobooks_data_validation.npz')
validation_inputs, validation_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

npz = np.load('Audiobooks_data_test.npz')
test_inputs, test_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

# %%
input_size = 10
output_size = 2
hidden_layer_size = 50
    
model = tf.keras.Sequential([
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(output_size, activation='softmax') 
])



model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

batch_size = 100
max_epochs = 100

early_stopping = tf.keras.callbacks.EarlyStopping(patience=2)

model.fit(train_inputs,
          train_targets, 
          batch_size=batch_size, 
          epochs=max_epochs,
          callbacks=[early_stopping], 
          validation_data=(validation_inputs, validation_targets),
          verbose = 2
          )
# Out:
# Train on 3579 samples, validate on 447 samples
# Epoch 1/100
# 3579/3579 - 1s - loss: 0.6218 - accuracy: 0.6737 - val_loss: 0.4753 - val_accuracy: 0.8680
# Epoch 2/100
# 3579/3579 - 0s - loss: 0.3980 - accuracy: 0.8729 - val_loss: 0.3500 - val_accuracy: 0.8926
# Epoch 3/100
# 3579/3579 - 0s - loss: 0.3255 - accuracy: 0.8807 - val_loss: 0.3160 - val_accuracy: 0.8993
# Epoch 4/100
# 3579/3579 - 0s - loss: 0.3057 - accuracy: 0.8874 - val_loss: 0.2952 - val_accuracy: 0.8971
# Epoch 5/100
# 3579/3579 - 0s - loss: 0.2898 - accuracy: 0.8913 - val_loss: 0.2741 - val_accuracy: 0.9083
# Epoch 6/100
# 3579/3579 - 0s - loss: 0.2804 - accuracy: 0.8955 - val_loss: 0.2635 - val_accuracy: 0.9128
# Epoch 7/100
# 3579/3579 - 0s - loss: 0.2722 - accuracy: 0.8958 - val_loss: 0.2550 - val_accuracy: 0.9150
# Epoch 8/100
# 3579/3579 - 0s - loss: 0.2673 - accuracy: 0.8994 - val_loss: 0.2427 - val_accuracy: 0.9150
# Epoch 9/100
# 3579/3579 - 0s - loss: 0.2604 - accuracy: 0.9016 - val_loss: 0.2375 - val_accuracy: 0.9150
# Epoch 10/100
# 3579/3579 - 0s - loss: 0.2567 - accuracy: 0.9028 - val_loss: 0.2266 - val_accuracy: 0.9105
# Epoch 11/100
# 3579/3579 - 0s - loss: 0.2531 - accuracy: 0.9039 - val_loss: 0.2207 - val_accuracy: 0.9217
# Epoch 12/100
# 3579/3579 - 0s - loss: 0.2511 - accuracy: 0.9047 - val_loss: 0.2199 - val_accuracy: 0.9172
# Epoch 13/100
# 3579/3579 - 0s - loss: 0.2485 - accuracy: 0.9053 - val_loss: 0.2174 - val_accuracy: 0.9172
# Epoch 14/100
# 3579/3579 - 0s - loss: 0.2442 - accuracy: 0.9053 - val_loss: 0.2127 - val_accuracy: 0.9195
# Epoch 15/100
# 3579/3579 - 0s - loss: 0.2439 - accuracy: 0.9064 - val_loss: 0.2079 - val_accuracy: 0.9239
# Epoch 16/100
# 3579/3579 - 0s - loss: 0.2445 - accuracy: 0.9086 - val_loss: 0.2059 - val_accuracy: 0.9329
# Epoch 17/100
# 3579/3579 - 0s - loss: 0.2409 - accuracy: 0.9075 - val_loss: 0.2100 - val_accuracy: 0.9239
# Epoch 18/100
# 3579/3579 - 0s - loss: 0.2384 - accuracy: 0.9081 - val_loss: 0.2073 - val_accuracy: 0.9217

# %%
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
# Out:
# 448/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print('\nTest loss: {0:.2f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100.))
# Out:
# Test loss: 0.24. Test accuracy: 91.07%
